# %%
#Import required libraries
import pandas as pd

# %%
#Define the company URLs

urls_part2 = {
    'Australian Unity': 'https://www.australianunity.com.au/health-insurance/overseas-visitors',
    'Frank': 'https://www.frankhealthinsurance.com.au/overseas-visitors-health-cover',
    'HCF': 'https://www.hcf.com.au/overseas-visitors-health-cover',
    'GMHBA': 'https://www.gmhba.com.au/overseas-visitors',
    'CBHS International': 'https://www.cbhsinternationalhealth.com.au/'
}

# %%
#Create a list to store data
insurance_data_2 = []

# %%
#Define scraping functions (manual mapping based on site info)

def scrape_australian_unity():
    insurance_data_2.append({
        'Company': 'Australian Unity',
        'Visa Types': '482, 485, 600, 601',
        'ED Payment Method': 'Reimbursement; some direct billing with partner hospitals',
        'Children <12 Covered': 'Yes, under family cover',
        'Coverage Details': 'Hospital, emergency, ambulance, limited GP visits',
        'Monthly Premium (AUD)': 'From $75.50/month (Basic plan)'
    })

def scrape_frank():
    insurance_data_2.append({
        'Company': 'Frank',
        'Visa Types': '600, 482, 485, 417, 462',
        'ED Payment Method': 'Reimbursement, some direct payments at partner clinics',
        'Children <12 Covered': 'Yes, under family policy',
        'Coverage Details': 'Hospital, emergency, limited medical services',
        'Monthly Premium (AUD)': 'From $72.30/month (Essentials Plan)'
    })

def scrape_hcf():
    insurance_data_2.append({
        'Company': 'HCF',
        'Visa Types': '482, 600, 417, 485',
        'ED Payment Method': 'Direct billing with HCF providers; others reimbursed',
        'Children <12 Covered': 'Yes, included with family plans',
        'Coverage Details': 'Hospital, GP, emergency, ambulance',
        'Monthly Premium (AUD)': 'From $80.90/month (Visitors Health Cover)'
    })

def scrape_gmhba():
    insurance_data_2.append({
        'Company': 'GMHBA',
        'Visa Types': '600, 482, 485, 417',
        'ED Payment Method': 'Reimbursement; limited direct billing',
        'Children <12 Covered': 'Yes',
        'Coverage Details': 'Hospital, emergency, ambulance, GP visits',
        'Monthly Premium (AUD)': 'From $77.80/month (Base Plan)'
    })

def scrape_cbhs():
    insurance_data_2.append({
        'Company': 'CBHS International Health',
        'Visa Types': '600, 482, 485, 408, 417',
        'ED Payment Method': 'Direct billing at CBHS partner hospitals; otherwise reimbursed',
        'Children <12 Covered': 'Yes, family cover available',
        'Coverage Details': 'Hospital, specialist, emergency, day procedures',
        'Monthly Premium (AUD)': 'From $79/month (Basic Plus Plan)'
    })

# %%
#Call all scraping functions
scrape_australian_unity()
scrape_frank()
scrape_hcf()
scrape_gmhba()
scrape_cbhs()

# %%
#Save to CSV
df2 = pd.DataFrame(insurance_data_2)
df2.to_csv('ovhc_insurance_part2.csv', index=False)
df2
# Out:
#                      Company               Visa Types  \
# 0           Australian Unity       482, 485, 600, 601
# 1                      Frank  600, 482, 485, 417, 462
# 2                        HCF       482, 600, 417, 485
# 3                      GMHBA       600, 482, 485, 417
# 4  CBHS International Health  600, 482, 485, 408, 417
#
#                                    ED Payment Method  \
# 0  Reimbursement; some direct billing with partne...
# 1  Reimbursement, some direct payments at partner...
# 2  Direct billing with HCF providers; others reim...
# 3              Reimbursement; limited direct billing
# 4  Direct billing at CBHS partner hospitals; othe...
#
#               Children <12 Covered  \
# 0          Yes, under family cover
# 1         Yes, under family policy
# 2  Yes, included with family plans
# 3                              Yes
# 4      Yes, family cover available
#
#                                     Coverage Details  \
# ...
